# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.set(style='darkgrid')
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic=sns.load_dataset('titanic')
titanic=pd.DataFrame(titanic)
#titanic
sns.catplot(x='day',y='total_bill',data=tips,jitter=False,hue='size')

# %%
sns.catplot(y='day',x='total_bill',data=tips,hue='size',kind='box',dodge=False)

# %%
sns.catplot(y='day',x='total_bill',data=tips,hue='size',kind='box',dodge=True)

# %%
sns.catplot(x='day',y='total_bill',data=tips,hue='size',kind='swarm')

# %%
sns.catplot(x='day',y='total_bill',data=tips,hue='sex',kind='violin',dodge=False,split=True)

# %%
sns.catplot(x='day',y='total_bill',data=tips,hue='size',kind='violin',dodge=False,split=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-da7cb3d57415> in <module>
# ----> 1 sns.catplot(x='day',y='total_bill',data=tips,hue='size',kind='violin',dodge=False,split=True)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3753
#    3754     # Draw the plot onto the facets
# -> 3755     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3756
#    3757     # Special case axis labels for a count type plot
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     818
#     819             # Draw the plot
# ...

# %%
x=np.random.randn(500)
sns.distplot(x,kde=False)

# %%
x=np.random.randn(500)
sns.distplot(x,kde=True)

# %%
x=np.random.randn(500)
sns.distplot(x,kde=False,bins=40)

# %%
x=np.random.randn(500)
sns.distplot(x,kde=True,bins=40)

# %%
x=np.random.randn(500)
sns.distplot(x,kde=False,rug=True)

# %%
x=np.random.randn(500)
sns.distplot(x,kde=True,rug=True,hist=False)

# %%
sns.kdeplot(x,shade=True)

# %%
sns.kdeplot(x,shade=True,bw=0.2)

# %%
sns.kdeplot(x,shade=True,bw=0.2,cut=0.2)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.pairplot(tips)

# %%
g=sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot,n_levels=6)

# %%
sns.regplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)
